# %%
import os
os.chdir("D:\SEM - 6\Machine Learning\Viswanathan")

# %%
"""
Author: Thirunavukkarasu J
Reg no: 19BDS0146
Vellore University of Technology, Vellore
Course Title: Machine Learning
"""
# Out:
# '\nAuthor: Thirunavukkarasu J\nReg no: 19BDS0146\nVellore University of Technology, Vellore\nCourse Title: Machine Learning\n'

# %%
import numpy as nm
import pandas as pd
import matplotlib.pyplot as mtp  
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("ndata.csv")
df = df.drop(['Unnamed: 32','id'], axis=1)
df.diagnosis.replace(['M', 'B'], [1, 0], inplace=True)
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.describe().T
# Out:
#                          count        mean         std         min  \
# diagnosis                569.0    0.372583    0.483918    0.000000
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# Let's plot out just the first 5 variables (features)
sns.pairplot(df, vars = ['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean','area_mean'])

# %%
# Let's plot out just the first 5 variables (features)
sns.pairplot(df, hue = 'diagnosis', vars = ['radius_mean', 'texture_mean', 'perimeter_mean','area_mean'] )

# %% [markdown]
# #### Correlation analysis

# %%
mtp.figure(figsize=(20,12)) 
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Finding the Skewness

# %%
df_skew = pd.DataFrame(data={
    'skewness': df.skew()
})

df_skew
# Out:
#                          skewness
# diagnosis                0.528461
# radius_mean              0.942380
# texture_mean             0.650450
# perimeter_mean           0.990650
# area_mean                1.645732
# smoothness_mean          0.456324
# compactness_mean         1.190123
# concavity_mean           1.401180
# concave points_mean      1.171180
# symmetry_mean            0.725609
# fractal_dimension_mean   1.304489
# radius_se                3.088612
# texture_se               1.646444
# perimeter_se             3.443615
# area_se                  5.447186
# smoothness_se            2.314450
# compactness_se           1.902221
# concavity_se             5.110463
# concave points_se        1.444678
# symmetry_se              2.195133
# fractal_dimension_se     3.923969
# radius_worst             1.103115
# texture_worst            0.498321
# perimeter_worst          1.128164
# area_worst               1.859373
# smoothness_worst         0.415426
# ...

# %% [markdown]
# #### Log transformation our skewed data

# %%
df.radius_se = np.log(df.radius_se + 1)
df.perimeter_se = np.log(df.perimeter_se + 1)
df.area_se = np.log(df.area_se)
df.concavity_se = np.log(df.concavity_se + 1)
df.fractal_dimension_se = np.log(df.fractal_dimension_se)

# %% [markdown]
# #### Detect and remove the outliers with Z-score

# %%
from scipy import stats
z = np.abs(stats.zscore(df))
print(df.shape)
# Out:
# (569, 31)

# %%
df = df[(z < 3).all(axis=1)]
print(df.shape)
df.head()
# Out:
# (496, 31)
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 4          1        20.29         14.34          135.10     1297.0
# 5          1        12.45         15.70           82.57      477.1
# 6          1        18.25         19.98          119.60     1040.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 4          0.10030           0.13280          0.1980              0.10430
# 5          0.12780           0.17000          0.1578              0.08089
# 6          0.09463           0.10900          0.1127              0.07400
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# Note:
#
# 1.0 (Orange) = Benign (No Cancer)
#
# 0.0 (Blue) = Malignant (Cancer)

# %%
df['diagnosis'].value_counts()
# Out:
# 0    333
# 1    163
# Name: diagnosis, dtype: int64

# %%
sns.countplot(df['diagnosis'], label = "Count")
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
# We drop our "Diagnosis" feature and use all the remaining features in our dataframe to train the model.
X = df.drop(['diagnosis'], axis = 1)
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 4           0.13280          0.1980              0.10430         0.1809
# 5           0.17000          0.1578              0.08089         0.2087
# 6           0.10900          0.1127              0.07400         0.1794
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
y = df['diagnosis']
y.head()
y.shape
# Out:
# (496,)

# %% [markdown]
# #### Feature Engineering

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
x_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.20, random_state = 30)

# %%
print ('The size of our training "X" (input features) is', X_train.shape)
print ('\n')
print ('The size of our testing "X" (input features) is', X_test.shape)
print ('\n')
print ('The size of our training "y" (output feature) is', y_train.shape)
print ('\n')
print ('The size of our testing "y" (output features) is', y_test.shape)
# Out:
# The size of our training "X" (input features) is (396, 30)
#
#
# The size of our testing "X" (input features) is (100, 30)
#
#
# The size of our training "y" (output feature) is (396,)
#
#
# The size of our testing "y" (output features) is (100,)

# %% [markdown]
# #### Linear Model

# %%
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
from sklearn.svm import SVC
svc_model = SVC(kernel='linear')
svc_model.fit(X_train, y_train)
y_predict = svc_model.predict(X_test)

# %%
# Import metric libraries
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm = nm.array(confusion_matrix(y_test, y_predict, labels=[1,0]))
confusion = pd.DataFrame(cm, index=['is_cancer', 'is_healthy'],
                         columns=['predicted_cancer','predicted_healthy'])
confusion
# Out:
#             predicted_cancer  predicted_healthy
# is_cancer                 29                  4
# is_healthy                 2                 65

# %%
sns.heatmap(confusion, annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96        67
#            1       0.94      0.88      0.91        33
#
#     accuracy                           0.94       100
#    macro avg       0.94      0.92      0.93       100
# weighted avg       0.94      0.94      0.94       100

# %%
from sklearn.metrics import accuracy_score
print("Accuracy of the Linear Model:",accuracy_score(y_test,y_predict))
# Out:
# Accuracy of the Linear Model: 0.94

# %% [markdown]
# #### Polynomial kernel

# %%
from sklearn.svm import SVC
svc_model = SVC(kernel='poly', degree=8)
svc_model.fit(X_train, y_train)
# Out:
# SVC(degree=8, kernel='poly')

# %%
y_predict = svc_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm = nm.array(confusion_matrix(y_test, y_predict, labels=[1,0]))
confusion = pd.DataFrame(cm, index=['is_cancer', 'is_healthy'],
                         columns=['predicted_cancer','predicted_healthy'])
confusion
# Out:
#             predicted_cancer  predicted_healthy
# is_cancer                 24                  9
# is_healthy                 1                 66

# %%
sns.heatmap(confusion, annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93        67
#            1       0.96      0.73      0.83        33
#
#     accuracy                           0.90       100
#    macro avg       0.92      0.86      0.88       100
# weighted avg       0.91      0.90      0.90       100

# %%
print("Accuracy of the Polynomial Model:",accuracy_score(y_test,y_predict))
# Out:
# Accuracy of the Polynomial Model: 0.9

# %% [markdown]
# #### Guassion Kernel

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='rbf')
svclassifier.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_predict = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm = nm.array(confusion_matrix(y_test, y_predict, labels=[1,0]))
confusion = pd.DataFrame(cm, index=['is_cancer', 'is_healthy'],
                         columns=['predicted_cancer','predicted_healthy'])
confusion
# Out:
#             predicted_cancer  predicted_healthy
# is_cancer                 25                  8
# is_healthy                 1                 66

# %%
sns.heatmap(confusion, annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94        67
#            1       0.96      0.76      0.85        33
#
#     accuracy                           0.91       100
#    macro avg       0.93      0.87      0.89       100
# weighted avg       0.91      0.91      0.91       100

# %%
print("Accuracy of the Guassion Model:",accuracy_score(y_test,y_predict))
# Out:
# Accuracy of the Guassion Model: 0.91

# %% [markdown]
# #### Sigmoid Kernel

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='sigmoid')
svclassifier.fit(X_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_predict = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm = nm.array(confusion_matrix(y_test, y_predict, labels=[1,0]))
confusion = pd.DataFrame(cm, index=['is_cancer', 'is_healthy'],
                         columns=['predicted_cancer','predicted_healthy'])
confusion
# Out:
#             predicted_cancer  predicted_healthy
# is_cancer                  0                 33
# is_healthy                 0                 67

# %%
sns.heatmap(confusion, annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80        67
#            1       0.00      0.00      0.00        33
#
#     accuracy                           0.67       100
#    macro avg       0.34      0.50      0.40       100
# weighted avg       0.45      0.67      0.54       100

# %%
print("Accuracy of the Sigmoid Model:",accuracy_score(y_test,y_predict))
# Out:
# Accuracy of the Sigmoid Model: 0.67

# %% [markdown]
# #### conclusion

# %%
print("Performance of the Linear SVM Model = 94%")
print("Performance of the Polynomial Kernel Model = 91%")
print("Performance of the Gaussian Kernel Model = 90%")
print("Performance of the Sigmoid Model = 67%")
# Out:
# Performance of the Linear SVM Model = 94%
# Performance of the Polynomial Kernel Model = 91%
# Performance of the Gaussian Kernel Model = 90%
# Performance of the Sigmoid Model = 67%

# %% [markdown]
# 1. If we compare the performance of the different types of kernels we can clearly see that the sigmoid kernel performs the worst.
#
# 2. Amongst the Gaussian kernel and polynomial kernel, we can see that Gaussian kernel achieved a perfect 91% prediction rate while polynomial kernel misclassified few more instance.
#
# 3. Therefore the Gaussian kernel performed slightly better. However, there is no hard and fast rule as to which kernel performs best in every scenario. It is all about testing all the kernels and selecting the one with the best results on your test dataset.
